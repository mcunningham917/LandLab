# %%
from landlab.plot import imshow_grid
from landlab import RasterModelGrid, CLOSED_BOUNDARY, FIXED_VALUE_BOUNDARY
from landlab.components import FlowRouter, FastscapeEroder, LinearDiffuser
from matplotlib.pyplot import figure, show, plot, xlabel, ylabel, title
#from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
from landlab.io import write_esri_ascii
# %matplotlib inline 

import numpy as np

# %%
mg = RasterModelGrid((700, 700), 30.) # The grid is 200 rows by 100 columns, with dx = dy = 50 m.

for edge in (mg.nodes_at_left_edge, mg.nodes_at_right_edge):
             mg.status_at_node[edge] = CLOSED_BOUNDARY
for edge in (mg.nodes_at_top_edge, mg.nodes_at_bottom_edge):
             mg.status_at_node[edge] = FIXED_VALUE_BOUNDARY
        
z = mg.add_zeros('node', 'topographic__elevation')
initial_roughness = np.random.rand(mg.core_nodes.size)/100000.
mg.at_node['topographic__elevation'][mg.core_nodes] += initial_roughness

imshow_grid(mg, z, grid_units=['m','m'], var_name='Elevation (m)')

# %%
total_t = 10000000. # years
dt = 1000 # years
nt = int(total_t // dt) # number of time steps

uplift_rate = 0.001 # m/yr
uplift_per_step = uplift_rate * dt # depth (m) of uplift per timestep

# %%
fr = FlowRouter(mg, method='D8')
sp = FastscapeEroder(mg, K_sp=0.00005, m_sp=0.5, n_sp=1.0, threshold_sp=0., rainfall_intensity=1.)
                    
k_d = 0.5
lin_diffuse = LinearDiffuser(mg, linear_diffusivity=k_d )

meanElevationArray = []

# %%
for i in range(nt):
    fr.run_one_step() # route flow
    sp.run_one_step(dt) # fluvial incision
    lin_diffuse.run_one_step(dt) # linear diffusion
    mg.at_node['topographic__elevation'][mg.core_nodes] += uplift_per_step # add the uplift
    meanElevation = np.mean(z)
    maxElevation = np.max(z)
    meanElevationArray.append(meanElevation)
    
    if i % 100 == 0:
      print ("Completed loop ", i, " out of ", nt)
# Out:
# ('Completed loop ', 0, ' out of ', 1000)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-141-d578e6d2d742> in <module>()
#       1 for i in range(nt):
# ----> 2     fr.run_one_step() # route flow
#       3     sp.run_one_step(dt) # fluvial incision
#       4     lin_diffuse.run_one_step(dt) # linear diffusion
#       5     mg.at_node['topographic__elevation'][mg.core_nodes] += uplift_per_step # add the uplift
#
# /Users/Max/anaconda/lib/python2.7/site-packages/landlab/components/flow_routing/route_flow_dn.pyc in run_one_step(self, **kwds)
#     368
#     369         self._test_for_method_change(**kwds)
# --> 370         self.accumulate_flow()
#     371
#     372     @property
#
# /Users/Max/anaconda/lib/python2.7/site-packages/landlab/components/flow_accum/flow_accumulator.pyc in accumulate_flow(self, update_flow_director)
#     911             delta = flow_accum_bw._make_delta_array(nd)
#     912             D = flow_accum_bw._make_array_of_donors(r, delta)
# --> 913             s = flow_accum_bw.make_ordered_node_array(r)
#     914
#     915             # put theese in grid so that depression finder can use it.
#
# /Users/Max/anaconda/lib/python2.7/site-packages/landlab/components/flow_accum/flow_accum_bw.pyc in make_ordered_node_array(receiver_nodes)
#     238     add_it = dstack.add_to_stack
#     239     for k in baselevel_nodes:
# --> 240         add_it(k) #don't think this is a bottleneck, so no C++
#     241
#     242     return dstack.s
#
# /Users/Max/anaconda/lib/python2.7/site-packages/landlab/components/flow_accum/flow_accum_bw.pyc in add_to_stack(self, l)
#      71         """
#      72         # we invoke cython here to attempt to suppress Python's RecursionLimit
# ---> 73         self.j = _add_to_stack(l, self.j, self.s, self.delta, self.D)
#      74
#      75
#
# KeyboardInterrupt:

# %%
plt.figure(1)    
imshow_grid(mg, 'topographic__elevation', grid_units=['m','m'], var_name='Elevation (m)')
plt.title('Evolved Topography')
plt.show()

plt.figure(2)
plt.loglog(mg.at_node['drainage_area'][mg.core_nodes],mg.at_node['topographic__steepest_slope'][mg.core_nodes],'k.')
plt.xlabel('drainage area (m^2)')
plt.ylabel('slope (m/m)')
plt.title('Slope-Area Plot')
plt.show()

# %%
write_esri_ascii('FastScape_10Ma_1mmyr_mp5_n1_k5Minus5_10kyrTimeStep_30mRes_20kmBy20Km.txt', mg, 'topographic__elevation')

# %%
plt.figure(3)    
plt.plot(meanElevationArray)
axes = plt.gca()
axes.set_xlim([0,1200])
axes.set_ylim([0,1500])

plt.savefig('FastScape_10Ma_1mmyr_mp5_n1_k5Minus5_10kyrTimeStep_30mRes_20kmBy20Km_meanElevation.png')
